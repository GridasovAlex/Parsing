# %%
from bs4 import BeautifulSoup as BS
import pandas as pd
import html5lib
import requests

# %%
list_ = ['1', '2','3', '4']
string = ", ".join(list_)
print(string)
# Out:
# 1, 2, 3, 4

# %%
# создаем объект BeautifulSoup
with open("data/pars.html", encoding="utf-8") as file:
    scr = file.read()
soup = BS(scr ,'lxml')

# %%
title = soup.title
print(title.string)
# Out:
# Главная страница блога

# %% [markdown]
# ## Find()  Find_all()

# %%
# нахожу один конкретный див
blog_name = soup.find('div', class_='blog__title').string
print(blog_name)

print()
# нахожу все заголовик пост тайтл
all_post_title = soup.find_all('div', class_='post__title')
for item in all_post_title:
    print(item.find('h3').text)

print()
#глубокий поиск
post_1_text = soup.find_all('div', class_='user__post__info')[0].find('div', class_="post__text").text
print(post_1_text.strip()) 

print()
post_2_text = soup.find_all('div', class_='user__post__info')[1].find('div', class_="post__text").text
print(post_2_text.strip())
# Out:
# Блог
#
# Российская нейросеть сортирует пластик с точностью 95%
# Wi-Fi Hack одежда
# Twitter будет банить пользователей, которые желают смерти другим
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore
#                     et dolore magna aliqua. Vitae justo eget magna fermentum iaculis eu. Nibh sit amet commodo nulla
#                     facilisi nullam vehicula ipsum. Elit pellentesque habitant morbi tristique senectus et netus et
#                     malesuada.
#
# Semper risus in hendrerit gravida rutrum quisque. Imperdiet sed euismod nisi porta lorem mollis
#                     aliquam. Blandit massa enim nec dui nunc mattis enim. Enim neque volutpat ac tincidunt vitae semper.

# %% [markdown]
# ## find_perent() find_perents()

# %%
# возвращает блок до первого родителя
perent = soup.find_all('div', class_='post__title')[2].find_parent()
print(perent)

print("-----------------------------------------------------------------------------------------------------")
# Возвращает всех родителей
perents = soup.find('div', class_='post__title').find_parents()
print(perents)
# Out:
# <div class="user__post__info">
# <div class="post__title">
# <h3>Twitter будет банить пользователей, которые желают смерти другим</h3>
# </div>
# <div class="post__text">
#                     Lobortis scelerisque fermentum dui faucibus in ornare quam viverra orci. Eget lorem dolor sed
#                     viverra ipsum nunc aliquet. Nunc id cursus metus aliquam eleifend mi in nulla. Aliquam id diam
#                     maecenas ultricies mi eget mauris pharetra. Ut tortor pretium viverra suspendisse potenti.
#                 </div>
# </div>
# -----------------------------------------------------------------------------------------------------
# [<div class="user__post__info">
# <div class="post__title">
# <h3>Российская нейросеть сортирует пластик с точностью 95%</h3>
# </div>
# <div class="post__date">
#                     01.01.2020
#                 </div>
# <div class="post__text">
#                     Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore
#                     et dolore magna aliqua. Vitae justo eget magna fermentum iaculis eu. Nibh sit amet commodo nulla
#                     facilisi nullam vehicula ipsum. Elit pellentesque habitant morbi tristique senectus et netus et
#                     malesuada.
#                 </div>
# </div>, <div class="user__post">
# <div class="user__post__info">
# <div class="post__title">
# <h3>Российская нейросеть сортирует пластик с точностью 95%</h3>
# </div>
# <div class="post__date">
#                     01.01.2020
#                 </div>
# <div class="post__text">
#                     Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore
#                     et dolore magna aliqua. Vitae justo eget magna fermentum iaculis eu. Nibh sit amet commodo nulla
#                     facilisi nullam vehicula ipsum. Elit pellentesque habitant morbi tristique senectus et netus et
#                     malesuada.
#                 </div>
# </div>
# </div>, <div class="user__blog__wall">
# <div class="blog__title">Блог</div>
# <div class="user__post">
# <div class="user__post__info">
# <div class="post__title">
# <h3>Российская нейросеть сортирует пластик с точностью 95%</h3>
# </div>
# <div class="post__date">
#                     01.01.2020
#                 </div>
# <div class="post__text">
#                     Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore
#                     et dolore magna aliqua. Vitae justo eget magna fermentum iaculis eu. Nibh sit amet commodo nulla
#                     facilisi nullam vehicula ipsum. Elit pellentesque habitant morbi tristique senectus et netus et
#                     malesuada.
#                 </div>
# </div>
# </div>
# <div class="user__post">
# <div class="user__post__info">
# <div class="post__title">
# <h3>Wi-Fi Hack одежда</h3>
# </div>
# <div class="post__text">
#                     Semper risus in hendrerit gravida rutrum quisque. Imperdiet sed euismod nisi porta lorem mollis
#                     aliquam. Blandit massa enim nec dui nunc mattis enim. Enim neque volutpat ac tincidunt vitae semper.
#                 </div>
# </div>
# </div>
# <div class="user__post">
# <div class="user__post__info">
# <div class="post__title">
# <h3>Twitter будет банить пользователей, которые желают смерти другим</h3>
# </div>
# <div class="post__text">
#                     Lobortis scelerisque fermentum dui faucibus in ornare quam viverra orci. Eget lorem dolor sed
#                     viverra ipsum nunc aliquet. Nunc id cursus metus aliquam eleifend mi in nulla. Aliquam id diam
#                     maecenas ultricies mi eget mauris pharetra. Ut tortor pretium viverra suspendisse potenti.
#                 </div>
# </div>
# </div>
# </div>, <div class="container">
# <h1>Страница пользователя Mr. Anderson</h1>
# <h1>Ещё один h1 заголовок</h1>
# <div class="user__data">
# <div class="user__avatar">
# <img alt="" src="user_avatar.jpg"/>
# </div>
# <div class="user__info">
# <!--            <a href="" class="user__name">-->
# <!--                <span>Mrs Purple</span>-->
# <!--            </a>-->
# <div class="user__name" id="aaa">
# <span>Mr Anderson</span>
# </div>
# <div class="user__birth__date">
# <span>Дата рождения:</span>
# <span>01.01.1970</span>
# </div>
# <div class="user__city">
# <span class="city__label">Город:</span>
# <span>Los Angeles</span>
# </div>
# <!--            <a href="">ЕЩЁ КАКАЯ-ТО ССЫЛКА</a>-->
# <div class="social__networks">
# <p>Ссылки на соц.сети:</p>
# <ul>
# <li>
# <a href="http://instagram.com/username">Instagram</a>
# </li>
# <li>
# <a href="http://twitter.com/username">Twitter</a>
# </li>
# <li>
# <a href="http://youtube.com/username">Youtube</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="user__blog__wall">
# <div class="blog__title">Блог</div>
# <div class="user__post">
# <div class="user__post__info">
# <div class="post__title">
# <h3>Российская нейросеть сортирует пластик с точностью 95%</h3>
# </div>
# <div class="post__date">
#                     01.01.2020
#                 </div>
# <div class="post__text">
#                     Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore
#                     et dolore magna aliqua. Vitae justo eget magna fermentum iaculis eu. Nibh sit amet commodo nulla
#                     facilisi nullam vehicula ipsum. Elit pellentesque habitant morbi tristique senectus et netus et
#                     malesuada.
#                 </div>
# </div>
# </div>
# <div class="user__post">
# <div class="user__post__info">
# <div class="post__title">
# <h3>Wi-Fi Hack одежда</h3>
# </div>
# <div class="post__text">
#                     Semper risus in hendrerit gravida rutrum quisque. Imperdiet sed euismod nisi porta lorem mollis
#                     aliquam. Blandit massa enim nec dui nunc mattis enim. Enim neque volutpat ac tincidunt vitae semper.
#                 </div>
# </div>
# </div>
# <div class="user__post">
# <div class="user__post__info">
# <div class="post__title">
# <h3>Twitter будет банить пользователей, которые желают смерти другим</h3>
# </div>
# <div class="post__text">
#                     Lobortis scelerisque fermentum dui faucibus in ornare quam viverra orci. Eget lorem dolor sed
#                     viverra ipsum nunc aliquet. Nunc id cursus metus aliquam eleifend mi in nulla. Aliquam id diam
#                     maecenas ultricies mi eget mauris pharetra. Ut tortor pretium viverra suspendisse potenti.
#                 </div>
# </div>
# </div>
# </div>
# <div class="some__links">
# <a data-attr="shop_link" href="/supermarket/">Магазин</a>
# <a data-attr="777" href="/clothes/">Одежда для взрослых</a>
# </div>
# </div>, <body>
# <div class="container">
# <h1>Страница пользователя Mr. Anderson</h1>
# <h1>Ещё один h1 заголовок</h1>
# <div class="user__data">
# <div class="user__avatar">
# <img alt="" src="user_avatar.jpg"/>
# </div>
# <div class="user__info">
# <!--            <a href="" class="user__name">-->
# <!--                <span>Mrs Purple</span>-->
# <!--            </a>-->
# <div class="user__name" id="aaa">
# <span>Mr Anderson</span>
# </div>
# <div class="user__birth__date">
# <span>Дата рождения:</span>
# <span>01.01.1970</span>
# </div>
# <div class="user__city">
# <span class="city__label">Город:</span>
# <span>Los Angeles</span>
# </div>
# <!--            <a href="">ЕЩЁ КАКАЯ-ТО ССЫЛКА</a>-->
# <div class="social__networks">
# <p>Ссылки на соц.сети:</p>
# <ul>
# <li>
# <a href="http://instagram.com/username">Instagram</a>
# </li>
# <li>
# <a href="http://twitter.com/username">Twitter</a>
# </li>
# <li>
# <a href="http://youtube.com/username">Youtube</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="user__blog__wall">
# <div class="blog__title">Блог</div>
# <div class="user__post">
# <div class="user__post__info">
# <div class="post__title">
# <h3>Российская нейросеть сортирует пластик с точностью 95%</h3>
# </div>
# <div class="post__date">
#                     01.01.2020
#                 </div>
# <div class="post__text">
#                     Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore
#                     et dolore magna aliqua. Vitae justo eget magna fermentum iaculis eu. Nibh sit amet commodo nulla
#                     facilisi nullam vehicula ipsum. Elit pellentesque habitant morbi tristique senectus et netus et
#                     malesuada.
#                 </div>
# </div>
# </div>
# <div class="user__post">
# <div class="user__post__info">
# <div class="post__title">
# <h3>Wi-Fi Hack одежда</h3>
# </div>
# <div class="post__text">
#                     Semper risus in hendrerit gravida rutrum quisque. Imperdiet sed euismod nisi porta lorem mollis
#                     aliquam. Blandit massa enim nec dui nunc mattis enim. Enim neque volutpat ac tincidunt vitae semper.
#                 </div>
# </div>
# </div>
# <div class="user__post">
# <div class="user__post__info">
# <div class="post__title">
# <h3>Twitter будет банить пользователей, которые желают смерти другим</h3>
# </div>
# <div class="post__text">
#                     Lobortis scelerisque fermentum dui faucibus in ornare quam viverra orci. Eget lorem dolor sed
#                     viverra ipsum nunc aliquet. Nunc id cursus metus aliquam eleifend mi in nulla. Aliquam id diam
#                     maecenas ultricies mi eget mauris pharetra. Ut tortor pretium viverra suspendisse potenti.
#                 </div>
# </div>
# </div>
# </div>
# <div class="some__links">
# <a data-attr="shop_link" href="/supermarket/">Магазин</a>
# <a data-attr="777" href="/clothes/">Одежда для взрослых</a>
# </div>
# </div>
# </body>, <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Главная страница блога</title>
# <link href="style.css" rel="stylesheet"/>
# </head>
# <body>
# <div class="container">
# <h1>Страница пользователя Mr. Anderson</h1>
# <h1>Ещё один h1 заголовок</h1>
# <div class="user__data">
# <div class="user__avatar">
# <img alt="" src="user_avatar.jpg"/>
# </div>
# <div class="user__info">
# <!--            <a href="" class="user__name">-->
# <!--                <span>Mrs Purple</span>-->
# <!--            </a>-->
# <div class="user__name" id="aaa">
# <span>Mr Anderson</span>
# </div>
# <div class="user__birth__date">
# <span>Дата рождения:</span>
# <span>01.01.1970</span>
# </div>
# <div class="user__city">
# <span class="city__label">Город:</span>
# <span>Los Angeles</span>
# </div>
# <!--            <a href="">ЕЩЁ КАКАЯ-ТО ССЫЛКА</a>-->
# <div class="social__networks">
# <p>Ссылки на соц.сети:</p>
# <ul>
# <li>
# <a href="http://instagram.com/username">Instagram</a>
# </li>
# <li>
# <a href="http://twitter.com/username">Twitter</a>
# </li>
# <li>
# <a href="http://youtube.com/username">Youtube</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="user__blog__wall">
# <div class="blog__title">Блог</div>
# <div class="user__post">
# <div class="user__post__info">
# <div class="post__title">
# <h3>Российская нейросеть сортирует пластик с точностью 95%</h3>
# </div>
# <div class="post__date">
#                     01.01.2020
#                 </div>
# <div class="post__text">
#                     Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore
#                     et dolore magna aliqua. Vitae justo eget magna fermentum iaculis eu. Nibh sit amet commodo nulla
#                     facilisi nullam vehicula ipsum. Elit pellentesque habitant morbi tristique senectus et netus et
#                     malesuada.
#                 </div>
# </div>
# </div>
# <div class="user__post">
# <div class="user__post__info">
# <div class="post__title">
# <h3>Wi-Fi Hack одежда</h3>
# </div>
# <div class="post__text">
#                     Semper risus in hendrerit gravida rutrum quisque. Imperdiet sed euismod nisi porta lorem mollis
#                     aliquam. Blandit massa enim nec dui nunc mattis enim. Enim neque volutpat ac tincidunt vitae semper.
#                 </div>
# </div>
# </div>
# <div class="user__post">
# <div class="user__post__info">
# <div class="post__title">
# <h3>Twitter будет банить пользователей, которые желают смерти другим</h3>
# </div>
# <div class="post__text">
#                     Lobortis scelerisque fermentum dui faucibus in ornare quam viverra orci. Eget lorem dolor sed
#                     viverra ipsum nunc aliquet. Nunc id cursus metus aliquam eleifend mi in nulla. Aliquam id diam
#                     maecenas ultricies mi eget mauris pharetra. Ut tortor pretium viverra suspendisse potenti.
#                 </div>
# </div>
# </div>
# </div>
# <div class="some__links">
# <a data-attr="shop_link" href="/supermarket/">Магазин</a>
# <a data-attr="777" href="/clothes/">Одежда для взрослых</a>
# </div>
# </div>
# </body>
# </html>, <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Главная страница блога</title>
# <link href="style.css" rel="stylesheet"/>
# </head>
# <body>
# <div class="container">
# <h1>Страница пользователя Mr. Anderson</h1>
# <h1>Ещё один h1 заголовок</h1>
# <div class="user__data">
# <div class="user__avatar">
# <img alt="" src="user_avatar.jpg"/>
# </div>
# <div class="user__info">
# <!--            <a href="" class="user__name">-->
# <!--                <span>Mrs Purple</span>-->
# <!--            </a>-->
# <div class="user__name" id="aaa">
# <span>Mr Anderson</span>
# </div>
# <div class="user__birth__date">
# <span>Дата рождения:</span>
# <span>01.01.1970</span>
# </div>
# <div class="user__city">
# <span class="city__label">Город:</span>
# <span>Los Angeles</span>
# </div>
# <!--            <a href="">ЕЩЁ КАКАЯ-ТО ССЫЛКА</a>-->
# <div class="social__networks">
# <p>Ссылки на соц.сети:</p>
# <ul>
# <li>
# <a href="http://instagram.com/username">Instagram</a>
# </li>
# <li>
# <a href="http://twitter.com/username">Twitter</a>
# </li>
# <li>
# <a href="http://youtube.com/username">Youtube</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="user__blog__wall">
# <div class="blog__title">Блог</div>
# <div class="user__post">
# <div class="user__post__info">
# <div class="post__title">
# <h3>Российская нейросеть сортирует пластик с точностью 95%</h3>
# </div>
# <div class="post__date">
#                     01.01.2020
#                 </div>
# <div class="post__text">
#                     Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore
#                     et dolore magna aliqua. Vitae justo eget magna fermentum iaculis eu. Nibh sit amet commodo nulla
#                     facilisi nullam vehicula ipsum. Elit pellentesque habitant morbi tristique senectus et netus et
#                     malesuada.
#                 </div>
# </div>
# </div>
# <div class="user__post">
# <div class="user__post__info">
# <div class="post__title">
# <h3>Wi-Fi Hack одежда</h3>
# </div>
# <div class="post__text">
#                     Semper risus in hendrerit gravida rutrum quisque. Imperdiet sed euismod nisi porta lorem mollis
#                     aliquam. Blandit massa enim nec dui nunc mattis enim. Enim neque volutpat ac tincidunt vitae semper.
#                 </div>
# </div>
# </div>
# <div class="user__post">
# <div class="user__post__info">
# <div class="post__title">
# <h3>Twitter будет банить пользователей, которые желают смерти другим</h3>
# </div>
# <div class="post__text">
#                     Lobortis scelerisque fermentum dui faucibus in ornare quam viverra orci. Eget lorem dolor sed
#                     viverra ipsum nunc aliquet. Nunc id cursus metus aliquam eleifend mi in nulla. Aliquam id diam
#                     maecenas ultricies mi eget mauris pharetra. Ut tortor pretium viverra suspendisse potenti.
#                 </div>
# </div>
# </div>
# </div>
# <div class="some__links">
# <a data-attr="shop_link" href="/supermarket/">Магазин</a>
# <a data-attr="777" href="/clothes/">Одежда для взрослых</a>
# </div>
# </div>
# </body>
# </html>
# ]

# %% [markdown]
# ## find_next() find_previous()

# %%
next_elem = soup.find(class_="container").find_next()
print(next_elem.text)

previous_elem = soup.find_all('h1')[1].find_previous()
print(previous_elem) #если предыдущий элемент родитель, вернет целый блок
# Out:
# Страница пользователя Mr. Anderson
# <h1>Страница пользователя Mr. Anderson</h1>

# %% [markdown]
# ## find_next_sibling() find_previous_sibling()

# %% [markdown]
# # GO

# %%
game_name_list = []
game_genre_list = []
mean_estimation_list = []
game_platform_list = []

for n in range(1,605):
    url = f'https://www.playground.ru/games?release=all&sort=time&p={n}'
    igor = requests.get(url).text
    soup = BS(igor, 'lxml')

    items = soup.find_all('div', class_="info")
    for elem in items:
        # ищем имя
        name = elem.find('div', class_="media-heading title").find('a').text
        game_name_list.append(name)
            
        # ищем оценку
        # estimation = elem.find('span', class_="value js-game-rating-value").text
        # mean_estimation_list.append(estimation)
        
        # ищем жанры
        geners = elem.find('div', class_="meta-info").find_next().find_next_sibling().find_all('a')
        genre_list = []
        for gener in geners:
            genre_list.append(str(gener.get_text()))
        game_genre_list.append(genre_list)

        # ищем платформы
        platforms = elem.find('div', class_="meta-info").find_next().find_next_sibling().find_next_sibling().find_all('span')
        platform_list = []
        for platform in platforms:
            platform_list.append(str(platform.get_text()))
        game_platform_list.append(platform_list)
        
        
print(game_name_list)
print(game_genre_list)
print(game_platform_list)
# Out:
# ['Moscow Rush', 'Six Days in Fallujah', 'Asylum', 'GTR 3', 'Ready to Run', 'The Trench', 'Routine', 'Deep Down', 'Primal Carnage: Genesis', 'Static Sky', 'City of Titans', 'Terraria 2', 'Pantheon: Rise of the Fallen', 'Titanic: Honor and Glory', 'Eitr', 'NoseBound', 'Tangiers', 'Positron', 'Structure', 'No Trace', 'SteamDolls VR', 'Age of Wushu 2', 'Bloodborne 2', 'Rail Theory', 'Justice Online', 'Active Crowds', 'Installation 01', 'To Azimuth', 'The Wolf Among Us 2: A Telltale Series', 'Neopolis', 'TauCeti Unknown Origin', 'Fear Effect Reinvented', 'Tale of Ronin', 'Little Devil Inside', 'My Little Story: Reborn', 'Arena of Ares', 'Star Child', 'The Legacy Games', "Shadow's Kiss", 'Bunker', 'Ascendancy', 'Living Dark', 'AQP City', 'Wellspring: Altar of Roots', 'Once Upon A Time In Roswell', 'Корсары: Черная метка', 'Solar Warden', 'JackHammer', 'Life Beyond', 'Tala', 'Witchbrook', 'Seed (2020)', 'Lost Soul Aside', 'Above', 'Winterfall', 'Gyre: Nova State', 'Totem Teller', 'Knights of Light', 'Twin Soul', 'Forest of Liars', 'Max and Maya: Cat simulator', 'Stormdivers', 'Reign of Guilds', 'SUPERHOT JP', 'Dungeonhaven', 'Orphan Age', 'Kova', 'Planetrism', 'Realms of Conquest', 'Burden of Command', 'Nighthawks', 'Vokabulantis', 'Starflight 3', 'Resort', 'The NOTHING', 'Realms Beyond: Ashes of the Fallen', 'Project Awakening', "Forsaken Realms: Vahrin's Call", 'Russia 2055', 'Harry Potter: Magic Awakened', 'Descent: Underground', 'Transmission', 'Unholy', 'Ode to a Moon', "Tom Clancy's Splinter Cell: Next", 'Skin Deep', 'The Hero of Deathtrap Dungeon', 'Secret War', '3 Minutes to Midnight', 'Car Wash Simulator']
# [['Симулятор', 'Инди', 'От третьего лица'], ['Экшен', 'Шутер', 'Тактика', 'От первого лица'], ['Адвенчура', 'Ужасы', 'От первого лица'], ['Симулятор', 'Гонки', 'Автомобили'], ['Аркада'], ['Экшен'], ['Экшен', 'Адвенчура', 'Ужасы', 'Космос'], ['Ролевая', 'От третьего лица', 'Фэнтези', 'Кооператив', 'Подземелья'], ['Экшен', 'Адвенчура'], ['Стратегия', 'Киберпанк'], ['Ролевая', 'Мультиплеер'], ['Аркада', 'Стратегия'], ['Ролевая', 'MMO', 'Фэнтези'], ['Адвенчура'], ['Адвенчура', 'Ролевая'], ['Адвенчура', 'Логические'], ['Экшен', 'Адвенчура', 'Стелс'], ['Аркада', 'Мультиплеер', 'Мотоциклы', 'От третьего лица', 'Научная фантастика '], ['Экшен', 'Адвенчура'], ['Экшен', 'Шутер', 'Стелс', 'Вид сверху'], ['Адвенчура', 'От первого лица', 'Стимпанк'], ['Экшен', 'Адвенчура', 'MMO', 'Открытый мир'], ['Экшен', 'Адвенчура', 'От третьего лица'], ['Адвенчура', 'От третьего лица', 'Открытый мир'], ['Экшен', 'Ролевая', 'MMO', 'От третьего лица'], ['Экшен', 'Стратегия', 'Симулятор', 'Инди', 'Tower defence'], ['Экшен', 'Мультиплеер', 'Шутер', 'От первого лица'], ['Адвенчура', 'Логические'], ['Адвенчура'], ['Ролевая', 'Стратегия', 'RTS', 'Киберпанк'], ['Ролевая', 'Шутер', 'Научная фантастика ', 'Кооператив', 'Виртуальная реальность'], ['Экшен', 'Вид сверху', 'Киберпанк'], ['Адвенчура', 'Ролевая', 'Инди', 'Пошаговая', 'Фэнтези'], ['Экшен', 'Адвенчура', 'Ролевая', 'Инди', 'Кооператив'], ['Экшен', 'Адвенчура', 'Шутер', 'Ужасы', 'Инди', 'От первого лица'], ['Экшен', 'Ролевая', 'Мультиплеер', 'От третьего лица', 'Фэнтези'], ['Экшен', 'Платформер', 'Научная фантастика ', 'Виртуальная реальность'], ['Ролевая', 'Стратегия', 'Инди', 'Фэнтези'], ['Ролевая', 'MMO', 'Фэнтези'], ['Экшен', 'Мультиплеер', 'Инди', 'Ретро', 'Кооператив'], ['Стратегия', 'RTS', 'Фэнтези'], ['Адвенчура', 'Открытый мир', 'Киберпанк'], ['Экшен', 'Инди', 'От третьего лица', 'Открытый мир'], ['Ролевая', 'Инди', 'Пошаговая', 'Тактика', 'Фэнтези', 'Открытый мир'], ['Адвенчура', 'Ужасы'], ['Экшен', 'Адвенчура', 'Ролевая', 'Открытый мир'], ['Экшен', 'Стратегия', 'Шутер', 'RTS', 'Космос', 'Научная фантастика ', 'Кооператив'], [], ['Экшен', 'MMO', 'Открытый мир', 'Научная фантастика '], ['Адвенчура', 'Инди', 'Платформер'], [], ['Симулятор', 'MMO', 'Песочница'], ['Экшен', 'Слэшер', 'Фэнтези', 'Открытый мир'], ['Экшен', 'Адвенчура', 'Инди'], ['Экшен', 'Ролевая', 'Стратегия', 'Инди', 'Открытый мир'], ['Экшен', 'Ролевая', 'Инди', 'Открытый мир', 'Стимпанк'], ['Адвенчура', 'Логические', 'Инди'], ['Экшен', 'Ролевая', 'Инди', 'Фэнтези'], ['Адвенчура', 'Логические', 'Ужасы', 'Инди', 'Кооператив'], ['Адвенчура', 'Инди', 'Фэнтези'], ['Экшен', 'Ролевая', 'Инди', 'Другой симулятор', 'Зомби ', 'Открытый мир', 'Постапокалипсис', 'Юмор'], ['Экшен', 'Мультиплеер', 'Шутер', 'От третьего лица', 'Научная фантастика '], ['Экшен', 'Ролевая', 'MMO', 'От третьего лица', 'Фэнтези', 'Средневековье'], [], ['Экшен', 'Ролевая', 'Фэнтези'], ['Стратегия', 'Инди', 'Менеджер', 'Киберпанк'], ['Экшен', 'Адвенчура', 'Ролевая', 'Инди', 'Научная фантастика '], ['Экшен', 'Адвенчура', 'Ролевая', 'Инди', 'Научная фантастика '], ['Стратегия', 'Инди', 'RTS', 'Пошаговая'], ['Ролевая', 'Стратегия', 'Инди', 'Тактика'], ['Ролевая', 'Инди'], ['Адвенчура', 'Инди'], ['Ролевая', 'Открытый мир', 'Космос', 'Научная фантастика '], ['Адвенчура', 'Логические'], ['Экшен', 'Ролевая', 'Инди', 'Киберпанк'], ['Адвенчура', 'Ролевая', 'Пошаговая', 'Тактика', 'Вид сверху', 'Фэнтези'], ['Экшен', 'Ролевая', 'MMO', 'От третьего лица', 'Фэнтези'], ['Экшен', 'Ролевая', 'От третьего лица', 'Фэнтези', 'Кооператив'], ['Экшен', 'Мультиплеер', 'Шутер', 'Инди', 'Научная фантастика '], ['Ролевая', 'Карточная'], ['Экшен', 'Мультиплеер', 'Шутер', 'От третьего лица', 'Космос', 'Научная фантастика '], ['Симулятор', 'Инди', 'Автомобили', 'От первого лица'], ['Экшен', 'Ужасы', 'Инди', 'От первого лица'], ['Адвенчура', 'Выживание', 'Ужасы', 'Инди', 'От первого лица'], ['Экшен', 'Стелс'], ['Экшен', 'Стелс', 'Инди', 'От первого лица'], ['Ролевая', 'Инди', 'Тактика', 'Фэнтези'], [ ...
# [['PC'], ['PC', 'PS4', 'Xbox One', 'PS5', 'Xbox SX'], ['PC'], ['PC'], ['PS4'], ['PC'], ['PC'], ['PS5'], ['PC'], ['iOS', 'Android'], ['PC'], ['PC', 'PS Vita', 'PS4', 'Xbox One'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PS4', 'PS5'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC', 'PS4', 'Xbox One', 'PS5', 'Xbox SX'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC', 'PS4', 'Xbox One', 'Switch', 'PS5'], ['PC'], ['PC'], ['PS4'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PS4', 'PS5'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC', 'PS4'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC'], ['PS4'], ['PC'], ['PC'], ['iOS', 'Android'], ['PC', 'PS4', 'Xbox One', 'Switch'], ['PC'], ['PC'], ['PC'], ['PC', 'PS5', 'Xbox SX'], ['PC'], ['PC'], ['PC'], ['PC'], ['PC']]
